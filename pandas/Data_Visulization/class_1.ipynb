# %% [markdown]
# > **`What is Data Visualization ?`**
#
# Data Visualization is the representation of data in a graphical format. It allows users to see and understand patterns, trends, and insights in data. From simple bar charts to intricate 3D models, data visualization encompasses a wide range of techniques.
#
# > **`Why it is important?`**
#
# 1) Quick Insights from Data.
# 2) Informed Decision Making.
# 3) Audience Engagement.
# 4) Data Exploration.
#
# > **`What should we keep in mind ?`**
#
#  - Simplicity.
#  - Consistency.
#  - Accuracy.
#  - Intractivity.
#
# > **`Tools`**
#
#  - Python.
#  - R
#  - Excel.
#  - Power Bi.
#  - Tableue.
#
# > **`Python Libraries`**
#
#  - Pandas.
#  - Matplotlib.
#  - Plotly.
#  - Seaborn.
#
# > **`Types of Plots/Charts`**
#
#  - Scatter Plot.                **(Numerical Data,Numerical Data)**
#  - Bubble Plot.                **(Numerical Data,Numerical Data)**
#  - Line Plot/Trend Line Plot.   **(Numerical Data,Numerical Data)**
#  - Bar Plot.                    **(Categorical Data,Numerical Data)**
#  - Box Plot.                    **(Categorical Data,Numerical Data)**
#  - Pie Plot.                    **(Categorical Data,Numerical Data)**
#  - DoughNut Plot.               **(Categorical Data,Numerical Data)**
#  - Spider/Radar Plot.           **(Categorical Data,Numerical Data)**
#  - Geographical Plot.           **(Categorical Data,Numerical Data)**
#  - Area Plot.                   **(Categorical Data,Numerical Data)**

# %%
# import libraraies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

df=sns.load_dataset('titanic')

# %% [markdown]
# # **Plots Only Pandas**

# %%
df.plot(kind='scatter' , x='age',y='fare',c='g',figsize=(15,2))
plt.show()

# %%
df.groupby('sex')['fare'].mean().plot(kind='bar')
plt.show()

# %% [markdown]
# # **Seaborn**

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df,x='survived',y='fare',hue='sex')
plt.show()

# %% [markdown]
# # **Plotly**

# %%
fig=px.scatter(df,x='age',y='fare',color='sex')
fig
